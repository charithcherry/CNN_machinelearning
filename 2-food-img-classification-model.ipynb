# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/readyset/course/train1/dosa/t1342.JPG
# /kaggle/input/readyset/course/train1/dosa/t1583.JPG
# /kaggle/input/readyset/course/train1/dosa/t1726.JPG
# /kaggle/input/readyset/course/train1/dosa/t1224.JPG
# /kaggle/input/readyset/course/train1/dosa/t1647.JPG
# /kaggle/input/readyset/course/train1/dosa/t1204.JPG
# /kaggle/input/readyset/course/train1/dosa/t1034.JPG
# /kaggle/input/readyset/course/train1/dosa/t1539.JPG
# /kaggle/input/readyset/course/train1/dosa/t1465.JPG
# /kaggle/input/readyset/course/train1/dosa/t1795.JPG
# /kaggle/input/readyset/course/train1/dosa/t1312.JPG
# /kaggle/input/readyset/course/train1/dosa/t1783.JPG
# /kaggle/input/readyset/course/train1/dosa/t1266.JPG
# /kaggle/input/readyset/course/train1/dosa/t1181.JPG
# /kaggle/input/readyset/course/train1/dosa/t1874.JPG
# /kaggle/input/readyset/course/train1/dosa/t1831.JPG
# /kaggle/input/readyset/course/train1/dosa/t1144.JPG
# /kaggle/input/readyset/course/train1/dosa/t1794.JPG
# /kaggle/input/readyset/course/train1/dosa/t1036.JPG
# /kaggle/input/readyset/course/train1/dosa/t1590.JPG
# /kaggle/input/readyset/course/train1/dosa/t1265.JPG
# /kaggle/input/readyset/course/train1/dosa/t1023.JPG
# /kaggle/input/readyset/course/train1/dosa/t1385.JPG
# /kaggle/input/readyset/course/train1/dosa/t1069.JPG
# /kaggle/input/readyset/course/train1/dosa/t1328.JPG
# /kaggle/input/readyset/course/train1/dosa/t1686.JPG
# /kaggle/input/readyset/course/train1/dosa/t1699.JPG
# /kaggle/input/readyset/course/train1/dosa/t997.JPG
# /kaggle/input/readyset/course/train1/dosa/t1736.JPG
# /kaggle/input/readyset/course/train1/dosa/t1619.JPG
# /kaggle/input/readyset/course/train1/dosa/t1552.JPG
# /kaggle/input/readyset/course/train1/dosa/t1765.JPG
# /kaggle/input/readyset/course/train1/dosa/t1741.JPG
# /kaggle/input/readyset/course/train1/dosa/t1107.JPG
# /kaggle/input/readyset/course/train1/dosa/t1653.JPG
# /kaggle/input/readyset/course/train1/dosa/t1894.JPG
# /kaggle/input/readyset/course/train1/dosa/t1490.JPG
# /kaggle/input/readyset/course/train1/dosa/t1047.JPG
# /kaggle/input/readyset/course/train1/dosa/t1260.JPG
# /kaggle/input/readyset/course/train1/dosa/t1574.JPG
# /kaggle/input/readyset/course/train1/dosa/t1261.JPG
# /kaggle/input/readyset/course/train1/dosa/t1168.JPG
# /kaggle/input/readyset/course/train1/dosa/t1316.JPG
# /kaggle/input/readyset/course/train1/dosa/t1350.JPG
# /kaggle/input/readyset/course/train1/dosa/t1138.JPG
# /kaggle/input/readyset/course/train1/dosa/t1753.JPG
# /kaggle/input/readyset/course/train1/dosa/t1469.JPG
# /kaggle/input/readyset/course/train1/dosa/t1673.JPG
# /kaggle/input/readyset/course/train1/dosa/t1151.JPG
# /kaggle/input/readyset/course/train1/dosa/t1032.JPG
# /kaggle/input/readyset/course/train1/dosa/t1301.JPG
# /kaggle/input/readyset/course/train1/dosa/t1185.JPG
# /kaggle/input/readyset/course/train1/dosa/t1770.JPG
# /kaggle/input/readyset/course/train1/dosa/t1333.JPG
# /kaggle/input/readyset/course/train1/dosa/t1035.JPG
# /kaggle/input/readyset/course/train1/dosa/t1321.JPG
# /kaggle/input/readyset/course/train1/dosa/t1600.JPG
# /kaggle/input/readyset/course/train1/dosa/t1460.JPG
# /kaggle/input/readyset/course/train1/dosa/t1729.JPG
# /kaggle/input/readyset/course/train1/dosa/t1798.JPG
# /kaggle/input/readyset/course/train1/dosa/t1772.JPG
# /kaggle/input/readyset/course/train1/dosa/t1057.JPG
# /kaggle/input/readyset/course/train1/dosa/t1636.JPG
# /kaggle/input/readyset/course/train1/dosa/t1424.JPG
# /kaggle/input/readyset/course/train1/dosa/t1706.JPG
# /kaggle/input/readyset/course/train1/dosa/t1294.JPG
# /kaggle/input/readyset/course/train1/dosa/t1515.JPG
# /kaggle/input/readyset/course/train1/dosa/t1233.JPG
# /kaggle/input/readyset/course/train1/dosa/t1133.JPG
# /kaggle/input/readyset/course/train1/dosa/t1313.JPG
# /kaggle/input/readyset/course/train1/dosa/t1130.JPG
# /kaggle/input/readyset/course/train1/dosa/t1129.JPG
# /kaggle/input/readyset/course/train1/dosa/t1734.JPG
# /kaggle/input/readyset/course/train1/dosa/t1039.JPG
# /kaggle/input/readyset/course/train1/dosa/t1815.JPG
# /kaggle/input/readyset/course/train1/dosa/t1692.JPG
# /kaggle/input/readyset/course/train1/dosa/t1132.JPG
# /kaggle/input/readyset/course/train1/dosa/t1724.JPG
# /kaggle/input/readyset/course/train1/dosa/t1565.JPG
# /kaggle/input/readyset/course/train1/dosa/t1134.JPG
# /kaggle/input/readyset/course/train1/dosa/t1704.JPG
# /kaggle/input/readyset/course/train1/dosa/t1234.JPG
# /kaggle/input/readyset/course/train1/dosa/t1623.JPG
# /kaggle/input/readyset/course/train1/dosa/t1630.JPG
# /kaggle/input/readyset/course/train1/dosa/t1787.JPG
# /kaggle/input/readyset/course/train1/dosa/t1814.JPG
# /kaggle/input/readyset/course/train1/dosa/t1820.JPG
# /kaggle/input/readyset/course/train1/dosa/t1425.JPG
# /kaggle/input/readyset/course/train1/dosa/t1698.JPG
# /kaggle/input/readyset/course/train1/dosa/t1203.JPG
# /kaggle/input/readyset/course/train1/dosa/t1304.JPG
# /kaggle/input/readyset/course/train1/dosa/t1691.JPG
# /kaggle/input/readyset/course/train1/dosa/t1836.JPG
# /kaggle/input/readyset/course/train1/dosa/t1289.JPG
# /kaggle/input/readyset/course/train1/dosa/t1303.JPG
# /kaggle/input/readyset/course/train1/dosa/t1763.JPG
# /kaggle/input/readyset/course/train1/dosa/t1746.JPG
# /kaggle/input/readyset/course/train1/dosa/t1802.JPG
# /kaggle/input/readyset/course/train1/dosa/t1290.JPG
# /kaggle/input/readyset/course/train1/dosa/t1725.JPG
# /kaggle/input/readyset/course/train1/dosa/t1401.JPG
# /kaggle/input/readyset/course/train1/dosa/t1278.JPG
# /kaggle/input/readyset/course/train1/dosa/t1631.JPG
# /kaggle/input/readyset/course/train1/dosa/t1128.JPG
# /kaggle/input/readyset/course/train1/dosa/t1252.JPG
# /kaggle/input/readyset/course/train1/dosa/t1693.JPG
# /kaggle/input/readyset/course/train1/dosa/t1162.JPG
# /kaggle/input/readyset/course/train1/dosa/t992.JPG
# /kaggle/input/readyset/course/train1/dosa/t1243.JPG
# /kaggle/input/readyset/course/train1/dosa/t1380.JPG
# /kaggle/input/readyset/course/train1/dosa/t1560.JPG
# /kaggle/input/readyset/course/train1/dosa/t1099.JPG
# /kaggle/input/readyset/course/train1/dosa/t1796.JPG
# /kaggle/input/readyset/course/train1/dosa/t991.JPG
# /kaggle/input/readyset/course/train1/dosa/t1433.JPG
# /kaggle/input/readyset/course/train1/dosa/t1176.JPG
# /kaggle/input/readyset/course/train1/dosa/t1212.JPG
# /kaggle/input/readyset/course/train1/dosa/t1502.JPG
# /kaggle/input/readyset/course/train1/dosa/t1070.JPG
# /kaggle/input/readyset/course/train1/dosa/t1899.JPG
# /kaggle/input/readyset/course/train1/dosa/t1652.JPG
# /kaggle/input/readyset/course/train1/dosa/t1851.JPG
# /kaggle/input/readyset/course/train1/dosa/t1689.JPG
# /kaggle/input/readyset/course/train1/dosa/t1617.JPG
# /kaggle/input/readyset/course/train1/dosa/t1779.JPG
# /kaggle/input/readyset/course/train1/dosa/t1807.JPG
# /kaggle/input/readyset/course/train1/dosa/t1406.JPG
# /kaggle/input/readyset/course/train1/dosa/t1514.JPG
# /kaggle/input/readyset/course/train1/dosa/t1125.JPG
# /kaggle/input/readyset/course/train1/dosa/t1530.JPG
# /kaggle/input/readyset/course/train1/dosa/t1175.JPG
# /kaggle/input/readyset/course/train1/dosa/t1522.JPG
# /kaggle/input/readyset/course/train1/dosa/t1045.JPG
# /kaggle/input/readyset/course/train1/dosa/t1225.JPG
# /kaggle/input/readyset/course/train1/dosa/t1206.JPG
# /kaggle/input/readyset/course/train1/dosa/t1139.JPG
# /kaggle/input/readyset/course/train1/dosa/t1228.JPG
# /kaggle/input/readyset/course/train1/dosa/t1394.JPG
# /kaggle/input/readyset/course/train1/dosa/t1159.JPG
# /kaggle/input/readyset/course/train1/dosa/t1344.JPG
# /kaggle/input/readyset/course/train1/dosa/t1086.JPG
# /kaggle/input/readyset/course/train1/dosa/t1571.JPG
# /kaggle/input/readyset/course/train1/dosa/t1273.JPG
# /kaggle/input/readyset/course/train1/dosa/t1256.JPG
# /kaggle/input/readyset/course/train1/dosa/t1477.JPG
# /kaggle/input/readyset/course/train1/dosa/t1226.JPG
# /kaggle/input/readyset/course/train1/dosa/t1051.JPG
# /kaggle/input/readyset/course/train1/dosa/t1105.JPG
# /kaggle/input/readyset/course/train1/dosa/t1202.JPG
# /kaggle/input/readyset/course/train1/dosa/t1748.JPG
# /kaggle/input/readyset/course/train1/dosa/t1611.JPG
# /kaggle/input/readyset/course/train1/dosa/t1504.JPG
# /kaggle/input/readyset/course/train1/dosa/t1100.JPG
# /kaggle/input/readyset/course/train1/dosa/t1622.JPG
# /kaggle/input/readyset/course/train1/dosa/t1637.JPG
# /kaggle/input/readyset/course/train1/dosa/t1366.JPG
# /kaggle/input/readyset/course/train1/dosa/t1835.JPG
# /kaggle/input/readyset/course/train1/dosa/t1863.JPG
# /kaggle/input/readyset/course/train1/dosa/t1821.JPG
# /kaggle/input/readyset/course/train1/dosa/t1009.JPG
# /kaggle/input/readyset/course/train1/dosa/t1476.JPG
# /kaggle/input/readyset/course/train1/dosa/t1429.JPG
# /kaggle/input/readyset/course/train1/dosa/t1131.JPG
# /kaggle/input/readyset/course/train1/dosa/t1455.JPG
# /kaggle/input/readyset/course/train1/dosa/t1485.JPG
# /kaggle/input/readyset/course/train1/dosa/t1471.JPG
# /kaggle/input/readyset/course/train1/dosa/t1710.JPG
# /kaggle/input/readyset/course/train1/dosa/t1573.JPG
# /kaggle/input/readyset/course/train1/dosa/t1309.JPG
# /kaggle/input/readyset/course/train1/dosa/t1382.JPG
# /kaggle/input/readyset/course/train1/dosa/t1674.JPG
# /kaggle/input/readyset/course/train1/dosa/t985.JPG
# /kaggle/input/readyset/course/train1/dosa/t1892.JPG
# /kaggle/input/readyset/course/train1/dosa/t988.JPG
# /kaggle/input/readyset/course/train1/dosa/t1396.JPG
# /kaggle/input/readyset/course/train1/dosa/t1707.JPG
# /kaggle/input/readyset/course/train1/dosa/t1192.JPG
# /kaggle/input/readyset/course/train1/dosa/t1555.JPG
# /kaggle/input/readyset/course/train1/dosa/t1402.JPG
# /kaggle/input/readyset/course/train1/dosa/t1817.JPG
# /kaggle/input/readyset/course/train1/dosa/t1281.JPG
# /kaggle/input/readyset/course/train1/dosa/t1595.JPG
# /kaggle/input/readyset/course/train1/dosa/t1437.JPG
# /kaggle/input/readyset/course/train1/dosa/t1271.JPG
# /kaggle/input/readyset/course/train1/dosa/t1845.JPG
# /kaggle/input/readyset/course/train1/dosa/t1121.JPG
# /kaggle/input/readyset/course/train1/dosa/t1843.JPG
# /kaggle/input/readyset/course/train1/dosa/t1553.JPG
# /kaggle/input/readyset/course/train1/dosa/t1005.JPG
# /kaggle/input/readyset/course/train1/dosa/t1024.JPG
# /kaggle/input/readyset/course/train1/dosa/t1561.JPG
# /kaggle/input/readyset/course/train1/dosa/t1597.JPG
# /kaggle/input/readyset/course/train1/dosa/t1160.JPG
# /kaggle/input/readyset/course/train1/dosa/t1541.JPG
# /kaggle/input/readyset/course/train1/dosa/t1438.JPG
# /kaggle/input/readyset/course/train1/dosa/t1897.JPG
# /kaggle/input/readyset/course/train1/dosa/t1291.JPG
# /kaggle/input/readyset/course/train1/dosa/t1201.JPG
# /kaggle/input/readyset/course/train1/dosa/t1077.JPG
# /kaggle/input/readyset/course/train1/dosa/t1872.JPG
# /kaggle/input/readyset/course/train1/dosa/t1284.JPG
# /kaggle/input/readyset/course/train1/dosa/t1020.JPG
# /kaggle/input/readyset/course/train1/dosa/t1286.JPG
# /kaggle/input/readyset/course/train1/dosa/t1211.JPG
# /kaggle/input/readyset/course/train1/dosa/t1019.JPG
# /kaggle/input/readyset/course/train1/dosa/t1340.JPG
# /kaggle/input/readyset/course/train1/dosa/t1148.JPG
# /kaggle/input/readyset/course/train1/dosa/t1386.JPG
# /kaggle/input/readyset/course/train1/dosa/t1880.JPG
# /kaggle/input/readyset/course/train1/dosa/t1871.JPG
# /kaggle/input/readyset/course/train1/dosa/t1451.JPG
# /kaggle/input/readyset/course/train1/dosa/t1169.JPG
# /kaggle/input/readyset/course/train1/dosa/t1089.JPG
# /kaggle/input/readyset/course/train1/dosa/t1180.JPG
# /kaggle/input/readyset/course/train1/dosa/t1407.JPG
# /kaggle/input/readyset/course/train1/dosa/t1111.JPG
# /kaggle/input/readyset/course/train1/dosa/t1062.JPG
# /kaggle/input/readyset/course/train1/dosa/t1482.JPG
# /kaggle/input/readyset/course/train1/dosa/t1253.JPG
# /kaggle/input/readyset/course/train1/dosa/t1059.JPG
# /kaggle/input/readyset/course/train1/dosa/t1093.JPG
# /kaggle/input/readyset/course/train1/dosa/t1865.JPG
# /kaggle/input/readyset/course/train1/dosa/t1882.JPG
# /kaggle/input/readyset/course/train1/dosa/t1277.JPG
# /kaggle/input/readyset/course/train1/dosa/t1408.JPG
# /kaggle/input/readyset/course/train1/dosa/t1219.JPG
# /kaggle/input/readyset/course/train1/dosa/t986.JPG
# /kaggle/input/readyset/course/train1/dosa/t1788.JPG
# /kaggle/input/readyset/course/train1/dosa/t1812.JPG
# /kaggle/input/readyset/course/train1/dosa/t1092.JPG
# /kaggle/input/readyset/course/train1/dosa/t1602.JPG
# /kaggle/input/readyset/course/train1/dosa/t1621.JPG
# /kaggle/input/readyset/course/train1/dosa/t1103.JPG
# /kaggle/input/readyset/course/train1/dosa/t1607.JPG
# /kaggle/input/readyset/course/train1/dosa/t1875.JPG
# /kaggle/input/readyset/course/train1/dosa/t1400.JPG
# /kaggle/input/readyset/course/train1/dosa/t1196.JPG
# /kaggle/input/readyset/course/train1/dosa/t1792.JPG
# /kaggle/input/readyset/course/train1/dosa/t1167.JPG
# /kaggle/input/readyset/course/train1/dosa/t1890.JPG
# /kaggle/input/readyset/course/train1/dosa/t1468.JPG
# /kaggle/input/readyset/course/train1/dosa/t1450.JPG
# /kaggle/input/readyset/course/train1/dosa/t1097.JPG
# /kaggle/input/readyset/course/train1/dosa/t1577.JPG
# /kaggle/input/readyset/course/train1/dosa/t1591.JPG
# /kaggle/input/readyset/course/train1/dosa/t1282.JPG
# /kaggle/input/readyset/course/train1/dosa/t1829.JPG
# /kaggle/input/readyset/course/train1/dosa/t1124.JPG
# /kaggle/input/readyset/course/train1/dosa/t1267.JPG
# /kaggle/input/readyset/course/train1/dosa/t1315.JPG
# /kaggle/input/readyset/course/train1/dosa/t1696.JPG
# /kaggle/input/readyset/course/train1/dosa/t1668.JPG
# /kaggle/input/readyset/course/train1/dosa/t1512.JPG
# /kaggle/input/readyset/course/train1/dosa/t1362.JPG
# /kaggle/input/readyset/course/train1/dosa/t1839.JPG
# /kaggle/input/readyset/course/train1/dosa/t1283.JPG
# /kaggle/input/readyset/course/train1/dosa/t1801.JPG
# /kaggle/input/readyset/course/train1/dosa/t1575.JPG
# /kaggle/input/readyset/course/train1/dosa/t1847.JPG
# /kaggle/input/readyset/course/train1/dosa/t1358.JPG
# /kaggle/input/readyset/course/train1/dosa/t1063.JPG
# /kaggle/input/readyset/course/train1/dosa/t1436.JPG
# /kaggle/input/readyset/course/train1/dosa/t1161.JPG
# /kaggle/input/readyset/course/train1/dosa/t1246.JPG
# /kaggle/input/readyset/course/train1/dosa/t1789.JPG
# /kaggle/input/readyset/course/train1/dosa/t1076.JPG
# /kaggle/input/readyset/course/train1/dosa/t1528.JPG
# /kaggle/input/readyset/course/train1/dosa/t1091.JPG
# /kaggle/input/readyset/course/train1/dosa/t1825.JPG
# /kaggle/input/readyset/course/train1/dosa/t1687.JPG
# /kaggle/input/readyset/course/train1/dosa/t1335.JPG
# /kaggle/input/readyset/course/train1/dosa/t1448.JPG
# /kaggle/input/readyset/course/train1/dosa/t1537.JPG
# /kaggle/input/readyset/course/train1/dosa/t1299.JPG
# /kaggle/input/readyset/course/train1/dosa/t1412.JPG
# /kaggle/input/readyset/course/train1/dosa/t1464.JPG
# /kaggle/input/readyset/course/train1/dosa/t1378.JPG
# /kaggle/input/readyset/course/train1/dosa/t1156.JPG
# /kaggle/input/readyset/course/train1/dosa/t1885.JPG
# /kaggle/input/readyset/course/train1/dosa/t990.JPG
# /kaggle/input/readyset/course/train1/dosa/t1497.JPG
# /kaggle/input/readyset/course/train1/dosa/t1524.JPG
# /kaggle/input/readyset/course/train1/dosa/t1797.JPG
# /kaggle/input/readyset/course/train1/dosa/t1422.JPG
# /kaggle/input/readyset/course/train1/dosa/t1862.JPG
# /kaggle/input/readyset/course/train1/dosa/t1021.JPG
# /kaggle/input/readyset/course/train1/dosa/t1848.JPG
# /kaggle/input/readyset/course/train1/dosa/t1525.JPG
# /kaggle/input/readyset/course/train1/dosa/t1297.JPG
# /kaggle/input/readyset/course/train1/dosa/t1066.JPG
# /kaggle/input/readyset/course/train1/dosa/t1644.JPG
# /kaggle/input/readyset/course/train1/dosa/t1688.JPG
# /kaggle/input/readyset/course/train1/dosa/t1615.JPG
# /kaggle/input/readyset/course/train1/dosa/t1877.JPG
# /kaggle/input/readyset/course/train1/dosa/t1007.JPG
# /kaggle/input/readyset/course/train1/dosa/t1033.JPG
# /kaggle/input/readyset/course/train1/dosa/t1075.JPG
# /kaggle/input/readyset/course/train1/dosa/t1713.JPG
# /kaggle/input/readyset/course/train1/dosa/t1088.JPG
# /kaggle/input/readyset/course/train1/dosa/t1834.JPG
# /kaggle/input/readyset/course/train1/dosa/t1171.JPG
# /kaggle/input/readyset/course/train1/dosa/t1671.JPG
# /kaggle/input/readyset/course/train1/dosa/t1123.JPG
# /kaggle/input/readyset/course/train1/dosa/t1368.JPG
# /kaggle/input/readyset/course/train1/dosa/t1048.JPG
# /kaggle/input/readyset/course/train1/dosa/t1750.JPG
# /kaggle/input/readyset/course/train1/dosa/t1805.JPG
# /kaggle/input/readyset/course/train1/dosa/t1861.JPG
# /kaggle/input/readyset/course/train1/dosa/t1327.JPG
# /kaggle/input/readyset/course/train1/dosa/t1248.JPG
# /kaggle/input/readyset/course/train1/dosa/t1542.JPG
# /kaggle/input/readyset/course/train1/dosa/t1280.JPG
# /kaggle/input/readyset/course/train1/dosa/t1114.JPG
# /kaggle/input/readyset/course/train1/dosa/t1534.JPG
# /kaggle/input/readyset/course/train1/dosa/t1264.JPG
# /kaggle/input/readyset/course/train1/dosa/t1002.JPG
# /kaggle/input/readyset/course/train1/dosa/t1756.JPG
# /kaggle/input/readyset/course/train1/dosa/t1445.JPG
# /kaggle/input/readyset/course/train1/dosa/t1221.JPG
# /kaggle/input/readyset/course/train1/dosa/t1426.JPG
# /kaggle/input/readyset/course/train1/dosa/t1589.JPG
# /kaggle/input/readyset/course/train1/dosa/t1388.JPG
# /kaggle/input/readyset/course/train1/dosa/t1850.JPG
# /kaggle/input/readyset/course/train1/dosa/t1475.JPG
# /kaggle/input/readyset/course/train1/dosa/t1822.JPG
# /kaggle/input/readyset/course/train1/dosa/t1711.JPG
# /kaggle/input/readyset/course/train1/dosa/t1588.JPG
# /kaggle/input/readyset/course/train1/dosa/t1594.JPG
# /kaggle/input/readyset/course/train1/dosa/t1509.JPG
# /kaggle/input/readyset/course/train1/dosa/t1104.JPG
# /kaggle/input/readyset/course/train1/dosa/t1832.JPG
# /kaggle/input/readyset/course/train1/dosa/t1627.JPG
# /kaggle/input/readyset/course/train1/dosa/t1345.JPG
# /kaggle/input/readyset/course/train1/dosa/t1008.JPG
# /kaggle/input/readyset/course/train1/dosa/t1804.JPG
# /kaggle/input/readyset/course/train1/dosa/t1250.JPG
# /kaggle/input/readyset/course/train1/dosa/t1348.JPG
# /kaggle/input/readyset/course/train1/dosa/t1489.JPG
# /kaggle/input/readyset/course/train1/dosa/t1085.JPG
# /kaggle/input/readyset/course/train1/dosa/t1334.JPG
# /kaggle/input/readyset/course/train1/dosa/t1813.JPG
# /kaggle/input/readyset/course/train1/dosa/t1593.JPG
# /kaggle/input/readyset/course/train1/dosa/t1764.JPG
# /kaggle/input/readyset/course/train1/dosa/t1311.JPG
# /kaggle/input/readyset/course/train1/dosa/t1603.JPG
# /kaggle/input/readyset/course/train1/dosa/t1170.JPG
# /kaggle/input/readyset/course/train1/dosa/t1205.JPG
# /kaggle/input/readyset/course/train1/dosa/t1172.JPG
# /kaggle/input/readyset/course/train1/dosa/t1614.JPG
# /kaggle/input/readyset/course/train1/dosa/t1360.JPG
# /kaggle/input/readyset/course/train1/dosa/t1251.JPG
# /kaggle/input/readyset/course/train1/dosa/t1481.JPG
# /kaggle/input/readyset/course/train1/dosa/t1499.JPG
# /kaggle/input/readyset/course/train1/dosa/t1684.JPG
# /kaggle/input/readyset/course/train1/dosa/t980.JPG
# /kaggle/input/readyset/course/train1/dosa/t1466.JPG
# /kaggle/input/readyset/course/train1/dosa/t1376.JPG
# /kaggle/input/readyset/course/train1/dosa/t1662.JPG
# /kaggle/input/readyset/course/train1/dosa/t1220.JPG
# /kaggle/input/readyset/course/train1/dosa/t1643.JPG
# /kaggle/input/readyset/course/train1/dosa/t1656.JPG
# /kaggle/input/readyset/course/train1/dosa/t1785.JPG
# /kaggle/input/readyset/course/train1/dosa/t1404.JPG
# /kaggle/input/readyset/course/train1/dosa/t1633.JPG
# /kaggle/input/readyset/course/train1/dosa/t1536.JPG
# /kaggle/input/readyset/course/train1/dosa/t1055.JPG
# /kaggle/input/readyset/course/train1/dosa/t1840.JPG
# /kaggle/input/readyset/course/train1/dosa/t1106.JPG
# /kaggle/input/readyset/course/train1/dosa/t1178.JPG
# /kaggle/input/readyset/course/train1/dosa/t1866.JPG
# /kaggle/input/readyset/course/train1/dosa/t1578.JPG
# /kaggle/input/readyset/course/train1/dosa/t1413.JPG
# /kaggle/input/readyset/course/train1/dosa/t1660.JPG
# /kaggle/input/readyset/course/train1/dosa/t1118.JPG
# /kaggle/input/readyset/course/train1/dosa/t1027.JPG
# /kaggle/input/readyset/course/train1/dosa/t1629.JPG
# /kaggle/input/readyset/course/train1/dosa/t1218.JPG
# /kaggle/input/readyset/course/train1/dosa/t1554.JPG
# /kaggle/input/readyset/course/train1/dosa/t1142.JPG
# /kaggle/input/readyset/course/train1/dosa/t1146.JPG
# /kaggle/input/readyset/course/train1/dosa/t1390.JPG
# /kaggle/input/readyset/course/train1/dosa/t1678.JPG
# /kaggle/input/readyset/course/train1/dosa/t1058.JPG
# /kaggle/input/readyset/course/train1/dosa/t998.JPG
# /kaggle/input/readyset/course/train1/dosa/t1325.JPG
# /kaggle/input/readyset/course/train1/dosa/t1609.JPG
# /kaggle/input/readyset/course/train1/dosa/t1140.JPG
# /kaggle/input/readyset/course/train1/dosa/t1742.JPG
# /kaggle/input/readyset/course/train1/dosa/t1377.JPG
# /kaggle/input/readyset/course/train1/dosa/t1701.JPG
# /kaggle/input/readyset/course/train1/dosa/t1041.JPG
# /kaggle/input/readyset/course/train1/dosa/t1841.JPG
# /kaggle/input/readyset/course/train1/dosa/t1601.JPG
# /kaggle/input/readyset/course/train1/dosa/t1519.JPG
# /kaggle/input/readyset/course/train1/dosa/t1331.JPG
# /kaggle/input/readyset/course/train1/dosa/t1544.JPG
# /kaggle/input/readyset/course/train1/dosa/t1610.JPG
# /kaggle/input/readyset/course/train1/dosa/t1613.JPG
# /kaggle/input/readyset/course/train1/dosa/t1655.JPG
# /kaggle/input/readyset/course/train1/dosa/t1227.JPG
# /kaggle/input/readyset/course/train1/dosa/t1551.JPG
# /kaggle/input/readyset/course/train1/dosa/t1896.JPG
# /kaggle/input/readyset/course/train1/dosa/t1320.JPG
# /kaggle/input/readyset/course/train1/dosa/t1188.JPG
# /kaggle/input/readyset/course/train1/dosa/t1632.JPG
# /kaggle/input/readyset/course/train1/dosa/t1050.JPG
# /kaggle/input/readyset/course/train1/dosa/t1357.JPG
# /kaggle/input/readyset/course/train1/dosa/t981.JPG
# /kaggle/input/readyset/course/train1/dosa/t1773.JPG
# /kaggle/input/readyset/course/train1/dosa/t1521.JPG
# /kaggle/input/readyset/course/train1/dosa/t1884.JPG
# /kaggle/input/readyset/course/train1/dosa/t1061.JPG
# /kaggle/input/readyset/course/train1/dosa/t1217.JPG
# /kaggle/input/readyset/course/train1/dosa/t1166.JPG
# /kaggle/input/readyset/course/train1/dosa/t1222.JPG
# /kaggle/input/readyset/course/train1/dosa/t1669.JPG
# /kaggle/input/readyset/course/train1/dosa/t1072.JPG
# /kaggle/input/readyset/course/train1/dosa/t1658.JPG
# /kaggle/input/readyset/course/train1/dosa/t1276.JPG
# /kaggle/input/readyset/course/train1/dosa/t1498.JPG
# /kaggle/input/readyset/course/train1/dosa/t1533.JPG
# /kaggle/input/readyset/course/train1/dosa/t1566.JPG
# /kaggle/input/readyset/course/train1/dosa/t1060.JPG
# /kaggle/input/readyset/course/train1/dosa/t1543.JPG
# /kaggle/input/readyset/course/train1/dosa/t1182.JPG
# /kaggle/input/readyset/course/train1/dosa/t1279.JPG
# /kaggle/input/readyset/course/train1/dosa/t1761.JPG
# /kaggle/input/readyset/course/train1/dosa/t1547.JPG
# /kaggle/input/readyset/course/train1/dosa/t1665.JPG
# /kaggle/input/readyset/course/train1/dosa/t1078.JPG
# /kaggle/input/readyset/course/train1/dosa/t1208.JPG
# /kaggle/input/readyset/course/train1/dosa/t1886.JPG
# /kaggle/input/readyset/course/train1/dosa/t1879.JPG
# /kaggle/input/readyset/course/train1/dosa/t1649.JPG
# /kaggle/input/readyset/course/train1/dosa/t1046.JPG
# /kaggle/input/readyset/course/train1/dosa/t1037.JPG
# /kaggle/input/readyset/course/train1/dosa/t1193.JPG
# /kaggle/input/readyset/course/train1/dosa/t1084.JPG
# /kaggle/input/readyset/course/train1/dosa/t1540.JPG
# /kaggle/input/readyset/course/train1/dosa/t999.JPG
# /kaggle/input/readyset/course/train1/dosa/t1094.JPG
# /kaggle/input/readyset/course/train1/dosa/t1587.JPG
# /kaggle/input/readyset/course/train1/dosa/t1241.JPG
# /kaggle/input/readyset/course/train1/dosa/t1837.JPG
# /kaggle/input/readyset/course/train1/dosa/t1014.JPG
# /kaggle/input/readyset/course/train1/dosa/t1467.JPG
# /kaggle/input/readyset/course/train1/dosa/t1173.JPG
# /kaggle/input/readyset/course/train1/dosa/t1635.JPG
# /kaggle/input/readyset/course/train1/dosa/t1292.JPG
# /kaggle/input/readyset/course/train1/dosa/t1462.JPG
# /kaggle/input/readyset/course/train1/dosa/t1423.JPG
# /kaggle/input/readyset/course/train1/dosa/t1174.JPG
# /kaggle/input/readyset/course/train1/dosa/t1739.JPG
# /kaggle/input/readyset/course/train1/dosa/t1496.JPG
# /kaggle/input/readyset/course/train1/dosa/t996.JPG
# /kaggle/input/readyset/course/train1/dosa/t1461.JPG
# /kaggle/input/readyset/course/train1/dosa/t1409.JPG
# /kaggle/input/readyset/course/train1/dosa/t1648.JPG
# /kaggle/input/readyset/course/train1/dosa/t1096.JPG
# /kaggle/input/readyset/course/train1/dosa/t1229.JPG
# /kaggle/input/readyset/course/train1/dosa/t1365.JPG
# /kaggle/input/readyset/course/train1/dosa/t1608.JPG
# /kaggle/input/readyset/course/train1/dosa/t1191.JPG
# /kaggle/input/readyset/course/train1/dosa/t1231.JPG
# /kaggle/input/readyset/course/train1/dosa/t1616.JPG
# /kaggle/input/readyset/course/train1/dosa/t987.JPG
# /kaggle/input/readyset/course/train1/dosa/t1115.JPG
# /kaggle/input/readyset/course/train1/dosa/t1323.JPG
# /kaggle/input/readyset/course/train1/dosa/t1135.JPG
# /kaggle/input/readyset/course/train1/dosa/t1858.JPG
# /kaggle/input/readyset/course/train1/dosa/t1731.JPG
# /kaggle/input/readyset/course/train1/dosa/t1606.JPG
# /kaggle/input/readyset/course/train1/dosa/t1506.JPG
# /kaggle/input/readyset/course/train1/dosa/t1319.JPG
# /kaggle/input/readyset/course/train1/dosa/t1434.JPG
# /kaggle/input/readyset/course/train1/dosa/t1650.JPG
# /kaggle/input/readyset/course/train1/dosa/t1456.JPG
# /kaggle/input/readyset/course/train1/dosa/t1527.JPG
# /kaggle/input/readyset/course/train1/dosa/t1562.JPG
# /kaggle/input/readyset/course/train1/dosa/t1116.JPG
# /kaggle/input/readyset/course/train1/dosa/t1659.JPG
# /kaggle/input/readyset/course/train1/dosa/t1675.JPG
# /kaggle/input/readyset/course/train1/dosa/t1895.JPG
# /kaggle/input/readyset/course/train1/dosa/t1453.JPG
# /kaggle/input/readyset/course/train1/dosa/t1624.JPG
# /kaggle/input/readyset/course/train1/dosa/t1774.JPG
# /kaggle/input/readyset/course/train1/dosa/t1003.JPG
# /kaggle/input/readyset/course/train1/dosa/t1177.JPG
# /kaggle/input/readyset/course/train1/dosa/t1255.JPG
# /kaggle/input/readyset/course/train1/dosa/t994.JPG
# /kaggle/input/readyset/course/train1/dosa/t1677.JPG
# /kaggle/input/readyset/course/train1/dosa/t1275.JPG
# /kaggle/input/readyset/course/train1/dosa/t1432.JPG
# /kaggle/input/readyset/course/train1/dosa/t1095.JPG
# /kaggle/input/readyset/course/train1/dosa/t1769.JPG
# /kaggle/input/readyset/course/train1/dosa/t1526.JPG
# /kaggle/input/readyset/course/train1/dosa/t1110.JPG
# /kaggle/input/readyset/course/train1/dosa/t1411.JPG
# /kaggle/input/readyset/course/train1/dosa/t1339.JPG
# /kaggle/input/readyset/course/train1/dosa/t1599.JPG
# /kaggle/input/readyset/course/train1/dosa/t1184.JPG
# /kaggle/input/readyset/course/train1/dosa/t1067.JPG
# /kaggle/input/readyset/course/train1/dosa/t1760.JPG
# /kaggle/input/readyset/course/train1/dosa/t1898.JPG
# /kaggle/input/readyset/course/train1/dosa/t1230.JPG
# /kaggle/input/readyset/course/train1/dosa/t1300.JPG
# /kaggle/input/readyset/course/train1/dosa/t1247.JPG
# /kaggle/input/readyset/course/train1/dosa/t1150.JPG
# /kaggle/input/readyset/course/train1/dosa/t1029.JPG
# /kaggle/input/readyset/course/train1/dosa/t1387.JPG
# /kaggle/input/readyset/course/train1/dosa/t1859.JPG
# /kaggle/input/readyset/course/train1/dosa/t1079.JPG
# /kaggle/input/readyset/course/train1/dosa/t1598.JPG
# /kaggle/input/readyset/course/train1/dosa/t1263.JPG
# /kaggle/input/readyset/course/train1/dosa/t1563.JPG
# /kaggle/input/readyset/course/train1/dosa/t1122.JPG
# /kaggle/input/readyset/course/train1/dosa/t1550.JPG
# /kaggle/input/readyset/course/train1/dosa/t1071.JPG
# /kaggle/input/readyset/course/train1/dosa/t1194.JPG
# /kaggle/input/readyset/course/train1/dosa/t1421.JPG
# /kaggle/input/readyset/course/train1/dosa/t1038.JPG
# /kaggle/input/readyset/course/train1/dosa/t1457.JPG
# /kaggle/input/readyset/course/train1/dosa/t1449.JPG
# /kaggle/input/readyset/course/train1/dosa/t1584.JPG
# /kaggle/input/readyset/course/train1/dosa/t1579.JPG
# /kaggle/input/readyset/course/train1/dosa/t1209.JPG
# /kaggle/input/readyset/course/train1/dosa/t1781.JPG
# /kaggle/input/readyset/course/train1/dosa/t1215.JPG
# /kaggle/input/readyset/course/train1/dosa/t1697.JPG
# /kaggle/input/readyset/course/train1/dosa/t1356.JPG
# /kaggle/input/readyset/course/train1/dosa/t1052.JPG
# /kaggle/input/readyset/course/train1/dosa/t1043.JPG
# /kaggle/input/readyset/course/train1/dosa/t1472.JPG
# /kaggle/input/readyset/course/train1/dosa/t1605.JPG
# /kaggle/input/readyset/course/train1/dosa/t1127.JPG
# /kaggle/input/readyset/course/train1/dosa/t1508.JPG
# /kaggle/input/readyset/course/train1/dosa/t1523.JPG
# /kaggle/input/readyset/course/train1/dosa/t1782.JPG
# /kaggle/input/readyset/course/train1/dosa/t1501.JPG
# /kaggle/input/readyset/course/train1/dosa/t1258.JPG
# /kaggle/input/readyset/course/train1/dosa/t1676.JPG
# /kaggle/input/readyset/course/train1/dosa/t1694.JPG
# /kaggle/input/readyset/course/train1/dosa/t1307.JPG
# /kaggle/input/readyset/course/train1/dosa/t1856.JPG
# /kaggle/input/readyset/course/train1/dosa/t1596.JPG
# /kaggle/input/readyset/course/train1/dosa/t1087.JPG
# /kaggle/input/readyset/course/train1/dosa/t1442.JPG
# /kaggle/input/readyset/course/train1/dosa/t1663.JPG
# /kaggle/input/readyset/course/train1/dosa/t1645.JPG
# /kaggle/input/readyset/course/train1/dosa/t1216.JPG
# /kaggle/input/readyset/course/train1/dosa/t1372.JPG
# /kaggle/input/readyset/course/train1/dosa/t1491.JPG
# /kaggle/input/readyset/course/train1/dosa/t1728.JPG
# /kaggle/input/readyset/course/train1/dosa/t1745.JPG
# /kaggle/input/readyset/course/train1/dosa/t1732.JPG
# /kaggle/input/readyset/course/train1/dosa/t1492.JPG
# /kaggle/input/readyset/course/train1/dosa/t1838.JPG
# /kaggle/input/readyset/course/train1/dosa/t1120.JPG
# /kaggle/input/readyset/course/train1/dosa/t1042.JPG
# /kaggle/input/readyset/course/train1/dosa/t1054.JPG
# /kaggle/input/readyset/course/train1/dosa/t1559.JPG
# /kaggle/input/readyset/course/train1/dosa/t1625.JPG
# /kaggle/input/readyset/course/train1/dosa/t1392.JPG
# /kaggle/input/readyset/course/train1/dosa/t1480.JPG
# /kaggle/input/readyset/course/train1/dosa/t1545.JPG
# /kaggle/input/readyset/course/train1/dosa/t1494.JPG
# /kaggle/input/readyset/course/train1/dosa/t1274.JPG
# /kaggle/input/readyset/course/train1/dosa/t1846.JPG
# /kaggle/input/readyset/course/train1/dosa/t1026.JPG
# /kaggle/input/readyset/course/train1/dosa/t1695.JPG
# /kaggle/input/readyset/course/train1/dosa/t1670.JPG
# /kaggle/input/readyset/course/train1/dosa/t1016.JPG
# /kaggle/input/readyset/course/train1/dosa/t1410.JPG
# /kaggle/input/readyset/course/train1/dosa/t1793.JPG
# /kaggle/input/readyset/course/train1/dosa/t1878.JPG
# /kaggle/input/readyset/course/train1/dosa/t1435.JPG
# /kaggle/input/readyset/course/train1/dosa/t1238.JPG
# /kaggle/input/readyset/course/train1/dosa/t1285.JPG
# /kaggle/input/readyset/course/train1/dosa/t1683.JPG
# /kaggle/input/readyset/course/train1/dosa/t1112.JPG
# /kaggle/input/readyset/course/train1/dosa/t1245.JPG
# /kaggle/input/readyset/course/train1/dosa/t1154.JPG
# /kaggle/input/readyset/course/train1/dosa/t1651.JPG
# /kaggle/input/readyset/course/train1/dosa/t1310.JPG
# /kaggle/input/readyset/course/train1/dosa/t1828.JPG
# /kaggle/input/readyset/course/train1/dosa/t1395.JPG
# /kaggle/input/readyset/course/train1/dosa/t1700.JPG
# /kaggle/input/readyset/course/train1/dosa/t1417.JPG
# /kaggle/input/readyset/course/train1/dosa/t1720.JPG
# /kaggle/input/readyset/course/train1/dosa/t1757.JPG
# /kaggle/input/readyset/course/train1/dosa/t1164.JPG
# /kaggle/input/readyset/course/train1/dosa/t1414.JPG
# /kaggle/input/readyset/course/train1/dosa/t1767.JPG
# /kaggle/input/readyset/course/train1/dosa/t1800.JPG
# /kaggle/input/readyset/course/train1/dosa/t1447.JPG
# /kaggle/input/readyset/course/train1/dosa/t1397.JPG
# /kaggle/input/readyset/course/train1/dosa/t1708.JPG
# /kaggle/input/readyset/course/train1/dosa/t1507.JPG
# /kaggle/input/readyset/course/train1/dosa/t1223.JPG
# /kaggle/input/readyset/course/train1/dosa/t1351.JPG
# /kaggle/input/readyset/course/train1/dosa/t1604.JPG
# /kaggle/input/readyset/course/train1/dosa/t1295.JPG
# /kaggle/input/readyset/course/train1/dosa/t1518.JPG
# /kaggle/input/readyset/course/train1/dosa/t1322.JPG
# /kaggle/input/readyset/course/train1/dosa/t1667.JPG
# /kaggle/input/readyset/course/train1/dosa/t1799.JPG
# /kaggle/input/readyset/course/train1/dosa/t1759.JPG
# /kaggle/input/readyset/course/train1/dosa/t1018.JPG
# /kaggle/input/readyset/course/train1/dosa/t1381.JPG
# /kaggle/input/readyset/course/train1/dosa/t1419.JPG
# /kaggle/input/readyset/course/train1/dosa/t1324.JPG
# /kaggle/input/readyset/course/train1/dosa/t1640.JPG
# /kaggle/input/readyset/course/train1/dosa/t1558.JPG
# /kaggle/input/readyset/course/train1/dosa/t1452.JPG
# /kaggle/input/readyset/course/train1/dosa/t1101.JPG
# /kaggle/input/readyset/course/train1/dosa/t983.JPG
# /kaggle/input/readyset/course/train1/dosa/t1143.JPG
# /kaggle/input/readyset/course/train1/dosa/t1314.JPG
# /kaggle/input/readyset/course/train1/dosa/t1535.JPG
# /kaggle/input/readyset/course/train1/dosa/t1902.JPG
# /kaggle/input/readyset/course/train1/dosa/t1240.JPG
# /kaggle/input/readyset/course/train1/dosa/t1183.JPG
# /kaggle/input/readyset/course/train1/dosa/t1336.JPG
# /kaggle/input/readyset/course/train1/dosa/t1842.JPG
# /kaggle/input/readyset/course/train1/dosa/t1000.JPG
# /kaggle/input/readyset/course/train1/dosa/t1017.JPG
# /kaggle/input/readyset/course/train1/dosa/t1723.JPG
# /kaggle/input/readyset/course/train1/dosa/t1766.JPG
# /kaggle/input/readyset/course/train1/dosa/t1666.JPG
# /kaggle/input/readyset/course/train1/dosa/t1347.JPG
# /kaggle/input/readyset/course/train1/dosa/t1567.JPG
# /kaggle/input/readyset/course/train1/dosa/t1338.JPG
# /kaggle/input/readyset/course/train1/dosa/t1065.JPG
# /kaggle/input/readyset/course/train1/dosa/t1405.JPG
# /kaggle/input/readyset/course/train1/dosa/t1889.JPG
# /kaggle/input/readyset/course/train1/dosa/t1510.JPG
# /kaggle/input/readyset/course/train1/dosa/t1317.JPG
# /kaggle/input/readyset/course/train1/dosa/t1353.JPG
# /kaggle/input/readyset/course/train1/dosa/t1415.JPG
# /kaggle/input/readyset/course/train1/dosa/t1022.JPG
# /kaggle/input/readyset/course/train1/dosa/t1268.JPG
# /kaggle/input/readyset/course/train1/dosa/t1374.JPG
# /kaggle/input/readyset/course/train1/dosa/t1520.JPG
# /kaggle/input/readyset/course/train1/dosa/t1028.JPG
# /kaggle/input/readyset/course/train1/dosa/t1818.JPG
# /kaggle/input/readyset/course/train1/dosa/t1098.JPG
# /kaggle/input/readyset/course/train1/dosa/t1443.JPG
# /kaggle/input/readyset/course/train1/dosa/t1262.JPG
# /kaggle/input/readyset/course/train1/dosa/t1270.JPG
# /kaggle/input/readyset/course/train1/dosa/t1416.JPG
# /kaggle/input/readyset/course/train1/dosa/t1532.JPG
# /kaggle/input/readyset/course/train1/dosa/t1439.JPG
# /kaggle/input/readyset/course/train1/dosa/t1483.JPG
# /kaggle/input/readyset/course/train1/dosa/t1570.JPG
# /kaggle/input/readyset/course/train1/dosa/t1900.JPG
# /kaggle/input/readyset/course/train1/dosa/t1463.JPG
# /kaggle/input/readyset/course/train1/dosa/t1833.JPG
# /kaggle/input/readyset/course/train1/dosa/t1305.JPG
# /kaggle/input/readyset/course/train1/dosa/t1053.JPG
# /kaggle/input/readyset/course/train1/dosa/t1440.JPG
# /kaggle/input/readyset/course/train1/dosa/t1308.JPG
# /kaggle/input/readyset/course/train1/dosa/t1197.JPG
# /kaggle/input/readyset/course/train1/dosa/t1853.JPG
# /kaggle/input/readyset/course/train1/dosa/t1152.JPG
# /kaggle/input/readyset/course/train1/dosa/t1867.JPG
# /kaggle/input/readyset/course/train1/dosa/t1207.JPG
# /kaggle/input/readyset/course/train1/dosa/t1459.JPG
# /kaggle/input/readyset/course/train1/dosa/t1716.JPG
# /kaggle/input/readyset/course/train1/dosa/t1011.JPG
# /kaggle/input/readyset/course/train1/dosa/t1398.JPG
# /kaggle/input/readyset/course/train1/dosa/t1883.JPG
# /kaggle/input/readyset/course/train1/dosa/t1389.JPG
# /kaggle/input/readyset/course/train1/dosa/t1733.JPG
# /kaggle/input/readyset/course/train1/dosa/t1717.JPG
# /kaggle/input/readyset/course/train1/dosa/t1626.JPG
# /kaggle/input/readyset/course/train1/dosa/t1620.JPG
# /kaggle/input/readyset/course/train1/dosa/t1364.JPG
# /kaggle/input/readyset/course/train1/dosa/t1702.JPG
# /kaggle/input/readyset/course/train1/dosa/t1639.JPG
# /kaggle/input/readyset/course/train1/dosa/t1006.JPG
# /kaggle/input/readyset/course/train1/dosa/t1431.JPG
# /kaggle/input/readyset/course/train1/dosa/t1823.JPG
# /kaggle/input/readyset/course/train1/dosa/t1546.JPG
# /kaggle/input/readyset/course/train1/dosa/t1790.JPG
# /kaggle/input/readyset/course/train1/dosa/t1010.JPG
# /kaggle/input/readyset/course/train1/dosa/t1680.JPG
# /kaggle/input/readyset/course/train1/dosa/t1454.JPG
# /kaggle/input/readyset/course/train1/dosa/t1393.JPG
# /kaggle/input/readyset/course/train1/dosa/t1737.JPG
# /kaggle/input/readyset/course/train1/dosa/t1015.JPG
# /kaggle/input/readyset/course/train1/dosa/t1379.JPG
# /kaggle/input/readyset/course/train1/dosa/t1758.JPG
# /kaggle/input/readyset/course/train1/dosa/t1158.JPG
# /kaggle/input/readyset/course/train1/dosa/t1025.JPG
# /kaggle/input/readyset/course/train1/dosa/t1511.JPG
# /kaggle/input/readyset/course/train1/dosa/t1113.JPG
# /kaggle/input/readyset/course/train1/dosa/t1893.JPG
# /kaggle/input/readyset/course/train1/dosa/t1383.JPG
# /kaggle/input/readyset/course/train1/dosa/t1854.JPG
# /kaggle/input/readyset/course/train1/dosa/t1458.JPG
# /kaggle/input/readyset/course/train1/dosa/t1403.JPG
# /kaggle/input/readyset/course/train1/dosa/t1549.JPG
# /kaggle/input/readyset/course/train1/dosa/t1102.JPG
# /kaggle/input/readyset/course/train1/dosa/t1249.JPG
# /kaggle/input/readyset/course/train1/dosa/t1791.JPG
# /kaggle/input/readyset/course/train1/dosa/t1080.JPG
# /kaggle/input/readyset/course/train1/dosa/t1399.JPG
# /kaggle/input/readyset/course/train1/dosa/t1341.JPG
# /kaggle/input/readyset/course/train1/dosa/t1780.JPG
# /kaggle/input/readyset/course/train1/dosa/t1826.JPG
# /kaggle/input/readyset/course/train1/dosa/t1163.JPG
# /kaggle/input/readyset/course/train1/dosa/t1585.JPG
# /kaggle/input/readyset/course/train1/dosa/t1493.JPG
# /kaggle/input/readyset/course/train1/dosa/t1369.JPG
# /kaggle/input/readyset/course/train1/dosa/t1446.JPG
# /kaggle/input/readyset/course/train1/dosa/t1714.JPG
# /kaggle/input/readyset/course/train1/dosa/t1343.JPG
# /kaggle/input/readyset/course/train1/dosa/t1778.JPG
# /kaggle/input/readyset/course/train1/dosa/t993.JPG
# /kaggle/input/readyset/course/train1/dosa/t1517.JPG
# /kaggle/input/readyset/course/train1/dosa/t1852.JPG
# /kaggle/input/readyset/course/train1/dosa/t1287.JPG
# /kaggle/input/readyset/course/train1/dosa/t1001.JPG
# /kaggle/input/readyset/course/train1/dosa/t1359.JPG
# /kaggle/input/readyset/course/train1/dosa/t1420.JPG
# /kaggle/input/readyset/course/train1/dosa/t1259.JPG
# /kaggle/input/readyset/course/train1/dosa/t1441.JPG
# /kaggle/input/readyset/course/train1/dosa/t1444.JPG
# /kaggle/input/readyset/course/train1/dosa/t1661.JPG
# /kaggle/input/readyset/course/train1/dosa/t1074.JPG
# /kaggle/input/readyset/course/train1/dosa/t1810.JPG
# /kaggle/input/readyset/course/train1/dosa/t1090.JPG
# /kaggle/input/readyset/course/train1/dosa/t1418.JPG
# /kaggle/input/readyset/course/train1/dosa/t1876.JPG
# /kaggle/input/readyset/course/train1/dosa/t1213.JPG
# /kaggle/input/readyset/course/train1/dosa/t1391.JPG
# /kaggle/input/readyset/course/train1/dosa/t1117.JPG
# /kaggle/input/readyset/course/train1/dosa/t1873.JPG
# /kaggle/input/readyset/course/train1/dosa/t1232.JPG
# /kaggle/input/readyset/course/train1/dosa/t1824.JPG
# /kaggle/input/readyset/course/train1/dosa/t1370.JPG
# /kaggle/input/readyset/course/train1/dosa/t1777.JPG
# /kaggle/input/readyset/course/train1/dosa/t1272.JPG
# /kaggle/input/readyset/course/train1/dosa/t1712.JPG
# /kaggle/input/readyset/course/train1/dosa/t1235.JPG
# /kaggle/input/readyset/course/train1/dosa/t1618.JPG
# /kaggle/input/readyset/course/train1/dosa/t1200.JPG
# /kaggle/input/readyset/course/train1/dosa/t1891.JPG
# /kaggle/input/readyset/course/train1/dosa/t1811.JPG
# /kaggle/input/readyset/course/train1/dosa/t1868.JPG
# /kaggle/input/readyset/course/train1/dosa/t1329.JPG
# /kaggle/input/readyset/course/train1/dosa/t1330.JPG
# /kaggle/input/readyset/course/train1/dosa/t1108.JPG
# /kaggle/input/readyset/course/train1/dosa/t1244.JPG
# /kaggle/input/readyset/course/train1/dosa/t1470.JPG
# /kaggle/input/readyset/course/train1/dosa/t1302.JPG
# /kaggle/input/readyset/course/train1/dosa/t1165.JPG
# /kaggle/input/readyset/course/train1/dosa/t1705.JPG
# /kaggle/input/readyset/course/train1/dosa/t1887.JPG
# /kaggle/input/readyset/course/train1/dosa/t1685.JPG
# /kaggle/input/readyset/course/train1/dosa/t1346.JPG
# /kaggle/input/readyset/course/train1/dosa/t1576.JPG
# /kaggle/input/readyset/course/train1/dosa/t1827.JPG
# /kaggle/input/readyset/course/train1/dosa/t1296.JPG
# /kaggle/input/readyset/course/train1/dosa/t1199.JPG
# /kaggle/input/readyset/course/train1/dosa/t1849.JPG
# /kaggle/input/readyset/course/train1/dosa/t1363.JPG
# /kaggle/input/readyset/course/train1/dosa/t1269.JPG
# /kaggle/input/readyset/course/train1/dosa/t1361.JPG
# /kaggle/input/readyset/course/train1/dosa/t1586.JPG
# /kaggle/input/readyset/course/train1/dosa/t1580.JPG
# /kaggle/input/readyset/course/train1/dosa/t1384.JPG
# /kaggle/input/readyset/course/train1/dosa/t1755.JPG
# /kaggle/input/readyset/course/train1/dosa/t1740.JPG
# /kaggle/input/readyset/course/train1/dosa/t1126.JPG
# /kaggle/input/readyset/course/train1/dosa/t1254.JPG
# /kaggle/input/readyset/course/train1/dosa/t1646.JPG
# /kaggle/input/readyset/course/train1/dosa/t1751.JPG
# /kaggle/input/readyset/course/train1/dosa/t1326.JPG
# /kaggle/input/readyset/course/train1/dosa/t1195.JPG
# /kaggle/input/readyset/course/train1/dosa/t995.JPG
# /kaggle/input/readyset/course/train1/dosa/t1473.JPG
# /kaggle/input/readyset/course/train1/dosa/t1427.JPG
# /kaggle/input/readyset/course/train1/dosa/t1141.JPG
# /kaggle/input/readyset/course/train1/dosa/t1556.JPG
# /kaggle/input/readyset/course/train1/dosa/t1242.JPG
# /kaggle/input/readyset/course/train1/dosa/t1568.JPG
# /kaggle/input/readyset/course/train1/dosa/t1888.JPG
# /kaggle/input/readyset/course/train1/dosa/t1430.JPG
# /kaggle/input/readyset/course/train1/dosa/t1147.JPG
# /kaggle/input/readyset/course/train1/dosa/t1762.JPG
# /kaggle/input/readyset/course/train1/dosa/t1870.JPG
# /kaggle/input/readyset/course/train1/dosa/t1190.JPG
# /kaggle/input/readyset/course/train1/dosa/t1638.JPG
# /kaggle/input/readyset/course/train1/dosa/t1495.JPG
# /kaggle/input/readyset/course/train1/dosa/t1869.JPG
# /kaggle/input/readyset/course/train1/dosa/t1505.JPG
# /kaggle/input/readyset/course/train1/dosa/t1738.JPG
# /kaggle/input/readyset/course/train1/dosa/t1715.JPG
# /kaggle/input/readyset/course/train1/dosa/t982.JPG
# /kaggle/input/readyset/course/train1/dosa/t1709.JPG
# /kaggle/input/readyset/course/train1/dosa/t1155.JPG
# /kaggle/input/readyset/course/train1/dosa/t1503.JPG
# /kaggle/input/readyset/course/train1/dosa/t1484.JPG
# /kaggle/input/readyset/course/train1/dosa/t1337.JPG
# /kaggle/input/readyset/course/train1/dosa/t1237.JPG
# /kaggle/input/readyset/course/train1/dosa/t1145.JPG
# /kaggle/input/readyset/course/train1/dosa/t1068.JPG
# /kaggle/input/readyset/course/train1/dosa/t1881.JPG
# /kaggle/input/readyset/course/train1/dosa/t1754.JPG
# /kaggle/input/readyset/course/train1/dosa/t984.JPG
# /kaggle/input/readyset/course/train1/dosa/t1548.JPG
# /kaggle/input/readyset/course/train1/dosa/t1844.JPG
# /kaggle/input/readyset/course/train1/dosa/t1582.JPG
# /kaggle/input/readyset/course/train1/dosa/t1488.JPG
# /kaggle/input/readyset/course/train1/dosa/t1634.JPG
# /kaggle/input/readyset/course/train1/dosa/t1516.JPG
# /kaggle/input/readyset/course/train1/dosa/t1136.JPG
# /kaggle/input/readyset/course/train1/dosa/t1214.JPG
# /kaggle/input/readyset/course/train1/dosa/t1367.JPG
# /kaggle/input/readyset/course/train1/dosa/t1730.JPG
# /kaggle/input/readyset/course/train1/dosa/t1198.JPG
# /kaggle/input/readyset/course/train1/dosa/t1809.JPG
# /kaggle/input/readyset/course/train1/dosa/t1749.JPG
# /kaggle/input/readyset/course/train1/dosa/t1727.JPG
# /kaggle/input/readyset/course/train1/dosa/t1855.JPG
# /kaggle/input/readyset/course/train1/dosa/t1257.JPG
# /kaggle/input/readyset/course/train1/dosa/t1013.JPG
# /kaggle/input/readyset/course/train1/dosa/t1682.JPG
# /kaggle/input/readyset/course/train1/dosa/t1056.JPG
# /kaggle/input/readyset/course/train1/dosa/t1808.JPG
# /kaggle/input/readyset/course/train1/dosa/t1612.JPG
# /kaggle/input/readyset/course/train1/dosa/t1044.JPG
# /kaggle/input/readyset/course/train1/dosa/t1153.JPG
# /kaggle/input/readyset/course/train1/dosa/t1803.JPG
# /kaggle/input/readyset/course/train1/dosa/t1478.JPG
# /kaggle/input/readyset/course/train1/dosa/t1012.JPG
# /kaggle/input/readyset/course/train1/dosa/t1236.JPG
# /kaggle/input/readyset/course/train1/dosa/t1428.JPG
# /kaggle/input/readyset/course/train1/dosa/t1371.JPG
# /kaggle/input/readyset/course/train1/dosa/t1642.JPG
# /kaggle/input/readyset/course/train1/dosa/t1641.JPG
# /kaggle/input/readyset/course/train1/dosa/t1901.JPG
# /kaggle/input/readyset/course/train1/dosa/t1149.JPG
# /kaggle/input/readyset/course/train1/dosa/t1513.JPG
# /kaggle/input/readyset/course/train1/dosa/t1816.JPG
# /kaggle/input/readyset/course/train1/dosa/t1040.JPG
# /kaggle/input/readyset/course/train1/dosa/t1581.JPG
# /kaggle/input/readyset/course/train1/dosa/t1375.JPG
# /kaggle/input/readyset/course/train1/dosa/t1332.JPG
# /kaggle/input/readyset/course/train1/dosa/t1479.JPG
# /kaggle/input/readyset/course/train1/dosa/t1857.JPG
# /kaggle/input/readyset/course/train1/dosa/t1572.JPG
# /kaggle/input/readyset/course/train1/dosa/t1752.JPG
# /kaggle/input/readyset/course/train1/dosa/t1718.JPG
# /kaggle/input/readyset/course/train1/dosa/t1864.JPG
# /kaggle/input/readyset/course/train1/dosa/t1073.JPG
# /kaggle/input/readyset/course/train1/dosa/t1819.JPG
# /kaggle/input/readyset/course/train1/dosa/t1564.JPG
# /kaggle/input/readyset/course/train1/dosa/t1189.JPG
# /kaggle/input/readyset/course/train1/dosa/t1747.JPG
# /kaggle/input/readyset/course/train1/dosa/t1239.JPG
# /kaggle/input/readyset/course/train1/dosa/t1681.JPG
# /kaggle/input/readyset/course/train1/dosa/t1298.JPG
# /kaggle/input/readyset/course/train1/dosa/t989.JPG
# /kaggle/input/readyset/course/train1/dosa/t1672.JPG
# /kaggle/input/readyset/course/train1/dosa/t1288.JPG
# /kaggle/input/readyset/course/train1/dosa/t1721.JPG
# /kaggle/input/readyset/course/train1/dosa/t1690.JPG
# /kaggle/input/readyset/course/train1/dosa/t1654.JPG
# /kaggle/input/readyset/course/train1/dosa/t1349.JPG
# /kaggle/input/readyset/course/train1/dosa/t1157.JPG
# /kaggle/input/readyset/course/train1/dosa/t1030.JPG
# /kaggle/input/readyset/course/train1/dosa/t1486.JPG
# /kaggle/input/readyset/course/train1/dosa/t1703.JPG
# /kaggle/input/readyset/course/train1/dosa/t1049.JPG
# /kaggle/input/readyset/course/train1/dosa/t1768.JPG
# /kaggle/input/readyset/course/train1/dosa/t1373.JPG
# /kaggle/input/readyset/course/train1/dosa/t1679.JPG
# /kaggle/input/readyset/course/train1/dosa/t1557.JPG
# /kaggle/input/readyset/course/train1/dosa/t1735.JPG
# /kaggle/input/readyset/course/train1/dosa/t1064.JPG
# /kaggle/input/readyset/course/train1/dosa/t1186.JPG
# /kaggle/input/readyset/course/train1/dosa/t1474.JPG
# /kaggle/input/readyset/course/train1/dosa/t1187.JPG
# /kaggle/input/readyset/course/train1/dosa/t1722.JPG
# /kaggle/input/readyset/course/train1/dosa/t1743.JPG
# /kaggle/input/readyset/course/train1/dosa/t1500.JPG
# /kaggle/input/readyset/course/train1/dosa/t1109.JPG
# /kaggle/input/readyset/course/train1/dosa/t1806.JPG
# /kaggle/input/readyset/course/train1/dosa/t1664.JPG
# /kaggle/input/readyset/course/train1/dosa/t1083.JPG
# /kaggle/input/readyset/course/train1/dosa/t1744.JPG
# /kaggle/input/readyset/course/train1/dosa/t1352.JPG
# /kaggle/input/readyset/course/train1/dosa/t1306.JPG
# /kaggle/input/readyset/course/train1/dosa/t1355.JPG
# /kaggle/input/readyset/course/train1/dosa/t1719.JPG
# /kaggle/input/readyset/course/train1/dosa/t1531.JPG
# /kaggle/input/readyset/course/train1/dosa/t1119.JPG
# /kaggle/input/readyset/course/train1/dosa/t1784.JPG
# /kaggle/input/readyset/course/train1/dosa/t1004.JPG
# /kaggle/input/readyset/course/train1/dosa/t1082.JPG
# /kaggle/input/readyset/course/train1/dosa/t1569.JPG
# /kaggle/input/readyset/course/train1/dosa/t1318.JPG
# /kaggle/input/readyset/course/train1/dosa/t1771.JPG
# /kaggle/input/readyset/course/train1/dosa/t1860.JPG
# /kaggle/input/readyset/course/train1/dosa/t1786.JPG
# /kaggle/input/readyset/course/train1/dosa/t1210.JPG
# /kaggle/input/readyset/course/train1/dosa/t1830.JPG
# /kaggle/input/readyset/course/train1/dosa/t1179.JPG
# /kaggle/input/readyset/course/train1/dosa/t1487.JPG
# /kaggle/input/readyset/course/train1/dosa/t1538.JPG
# /kaggle/input/readyset/course/train1/dosa/t1354.JPG
# /kaggle/input/readyset/course/train1/dosa/t1592.JPG
# /kaggle/input/readyset/course/train1/dosa/t1031.JPG
# /kaggle/input/readyset/course/train1/dosa/t1628.JPG
# /kaggle/input/readyset/course/train1/dosa/t1081.JPG
# /kaggle/input/readyset/course/train1/dosa/t1775.JPG
# /kaggle/input/readyset/course/train1/dosa/t1529.JPG
# /kaggle/input/readyset/course/train1/dosa/t1776.JPG
# /kaggle/input/readyset/course/train1/dosa/t1293.JPG
# /kaggle/input/readyset/course/train1/dosa/t1657.JPG
# /kaggle/input/readyset/course/train1/dosa/t1137.JPG
# ...
# /kaggle/input/readyset/course/test1/samosa/t495.JPG
# /kaggle/input/readyset/course/test1/samosa/t435.JPG
# /kaggle/input/readyset/course/test1/samosa/t423.JPG
# /kaggle/input/readyset/course/test1/samosa/t431.JPG
# /kaggle/input/readyset/course/test1/samosa/t493.JPG
# /kaggle/input/readyset/course/test1/samosa/t430.JPG
# /kaggle/input/readyset/course/test1/samosa/t481.JPG
# /kaggle/input/readyset/course/test1/samosa/t486.JPG
# /kaggle/input/readyset/course/test1/samosa/t478.JPG
# /kaggle/input/readyset/course/test1/samosa/t464.JPG
# /kaggle/input/readyset/course/test1/samosa/t452.JPG
# /kaggle/input/readyset/course/test1/samosa/t453.JPG
# /kaggle/input/readyset/course/test1/samosa/t461.JPG
# /kaggle/input/readyset/course/test1/samosa/t471.JPG
# /kaggle/input/readyset/course/test1/samosa/t444.JPG
# /kaggle/input/readyset/course/test1/butternaan/t73.JPG
# /kaggle/input/readyset/course/test1/butternaan/t13.JPG
# /kaggle/input/readyset/course/test1/butternaan/t25.JPG
# /kaggle/input/readyset/course/test1/butternaan/t2.JPG
# /kaggle/input/readyset/course/test1/butternaan/t51.JPG
# /kaggle/input/readyset/course/test1/butternaan/t8.JPG
# /kaggle/input/readyset/course/test1/butternaan/t64.JPG
# /kaggle/input/readyset/course/test1/butternaan/t42.JPG
# /kaggle/input/readyset/course/test1/butternaan/t14.JPG
# /kaggle/input/readyset/course/test1/butternaan/t80.JPG
# /kaggle/input/readyset/course/test1/butternaan/t68.JPG
# /kaggle/input/readyset/course/test1/butternaan/t47.JPG
# /kaggle/input/readyset/course/test1/butternaan/t46.JPG
# /kaggle/input/readyset/course/test1/butternaan/t57.JPG
# /kaggle/input/readyset/course/test1/butternaan/t15.JPG
# /kaggle/input/readyset/course/test1/butternaan/t33.JPG
# /kaggle/input/readyset/course/test1/butternaan/t95.JPG
# /kaggle/input/readyset/course/test1/butternaan/t74.JPG
# /kaggle/input/readyset/course/test1/butternaan/t3.JPG
# /kaggle/input/readyset/course/test1/butternaan/t29.JPG
# /kaggle/input/readyset/course/test1/butternaan/t87.JPG
# /kaggle/input/readyset/course/test1/butternaan/t86.JPG
# /kaggle/input/readyset/course/test1/butternaan/t12.JPG
# /kaggle/input/readyset/course/test1/butternaan/t49.JPG
# /kaggle/input/readyset/course/test1/butternaan/t92.JPG
# /kaggle/input/readyset/course/test1/butternaan/t23.JPG
# /kaggle/input/readyset/course/test1/butternaan/t79.JPG
# /kaggle/input/readyset/course/test1/butternaan/t17.JPG
# /kaggle/input/readyset/course/test1/butternaan/t7.JPG
# /kaggle/input/readyset/course/test1/butternaan/t90.JPG
# /kaggle/input/readyset/course/test1/butternaan/t19.JPG
# /kaggle/input/readyset/course/test1/butternaan/t30.JPG
# /kaggle/input/readyset/course/test1/butternaan/t52.JPG
# /kaggle/input/readyset/course/test1/butternaan/t55.JPG
# /kaggle/input/readyset/course/test1/butternaan/t5.JPG
# /kaggle/input/readyset/course/test1/butternaan/t60.JPG
# /kaggle/input/readyset/course/test1/butternaan/t96.JPG
# /kaggle/input/readyset/course/test1/butternaan/t28.JPG
# /kaggle/input/readyset/course/test1/butternaan/t99.JPG
# /kaggle/input/readyset/course/test1/butternaan/t11.JPG
# /kaggle/input/readyset/course/test1/butternaan/t53.JPG
# /kaggle/input/readyset/course/test1/butternaan/t84.JPG
# /kaggle/input/readyset/course/test1/butternaan/t38.JPG
# /kaggle/input/readyset/course/test1/butternaan/t58.JPG
# /kaggle/input/readyset/course/test1/butternaan/t81.JPG
# /kaggle/input/readyset/course/test1/butternaan/t32.JPG
# /kaggle/input/readyset/course/test1/butternaan/t89.JPG
# /kaggle/input/readyset/course/test1/butternaan/t22.JPG
# /kaggle/input/readyset/course/test1/butternaan/t35.JPG
# /kaggle/input/readyset/course/test1/butternaan/t100.JPG
# /kaggle/input/readyset/course/test1/butternaan/t36.JPG
# /kaggle/input/readyset/course/test1/butternaan/t71.JPG
# /kaggle/input/readyset/course/test1/butternaan/t94.JPG
# /kaggle/input/readyset/course/test1/butternaan/t72.JPG
# /kaggle/input/readyset/course/test1/butternaan/t76.JPG
# /kaggle/input/readyset/course/test1/butternaan/t24.JPG
# /kaggle/input/readyset/course/test1/butternaan/t66.JPG
# /kaggle/input/readyset/course/test1/butternaan/t48.JPG
# /kaggle/input/readyset/course/test1/butternaan/t82.JPG
# /kaggle/input/readyset/course/test1/butternaan/t34.JPG
# /kaggle/input/readyset/course/test1/butternaan/t63.JPG
# /kaggle/input/readyset/course/test1/butternaan/t75.JPG
# /kaggle/input/readyset/course/test1/butternaan/t40.JPG
# /kaggle/input/readyset/course/test1/butternaan/t67.JPG
# /kaggle/input/readyset/course/test1/butternaan/t77.JPG
# /kaggle/input/readyset/course/test1/butternaan/t45.JPG
# /kaggle/input/readyset/course/test1/butternaan/t50.JPG
# /kaggle/input/readyset/course/test1/butternaan/t21.JPG
# /kaggle/input/readyset/course/test1/butternaan/t39.JPG
# /kaggle/input/readyset/course/test1/butternaan/t85.JPG
# /kaggle/input/readyset/course/test1/butternaan/t44.JPG
# /kaggle/input/readyset/course/test1/butternaan/t65.JPG
# /kaggle/input/readyset/course/test1/butternaan/t54.JPG
# /kaggle/input/readyset/course/test1/butternaan/t4.JPG
# /kaggle/input/readyset/course/test1/butternaan/t9.JPG
# /kaggle/input/readyset/course/test1/butternaan/t88.JPG
# /kaggle/input/readyset/course/test1/butternaan/t59.JPG
# /kaggle/input/readyset/course/test1/butternaan/t69.JPG
# /kaggle/input/readyset/course/test1/butternaan/t10.JPG
# /kaggle/input/readyset/course/test1/butternaan/t18.JPG
# /kaggle/input/readyset/course/test1/butternaan/t91.JPG
# /kaggle/input/readyset/course/test1/butternaan/t70.JPG
# /kaggle/input/readyset/course/test1/butternaan/t6.JPG
# /kaggle/input/readyset/course/test1/butternaan/t41.JPG
# /kaggle/input/readyset/course/test1/butternaan/t1.JPG
# /kaggle/input/readyset/course/test1/butternaan/t26.JPG
# /kaggle/input/readyset/course/test1/butternaan/t62.JPG
# /kaggle/input/readyset/course/test1/butternaan/t83.JPG
# /kaggle/input/readyset/course/test1/butternaan/t98.JPG
# /kaggle/input/readyset/course/test1/butternaan/t61.JPG
# /kaggle/input/readyset/course/test1/butternaan/t78.JPG
# /kaggle/input/readyset/course/test1/butternaan/t37.JPG
# /kaggle/input/readyset/course/test1/butternaan/t31.JPG
# /kaggle/input/readyset/course/test1/butternaan/t56.JPG
# /kaggle/input/readyset/course/test1/butternaan/t16.JPG
# /kaggle/input/readyset/course/test1/butternaan/t27.JPG
# /kaggle/input/readyset/course/test1/butternaan/t97.JPG
# /kaggle/input/readyset/course/test1/butternaan/t43.JPG
# /kaggle/input/readyset/course/test1/butternaan/t20.JPG
# /kaggle/input/readyset/course/test1/butternaan/t93.JPG
# /kaggle/input/readyset/course/test1/dhokla/t247.JPG
# /kaggle/input/readyset/course/test1/dhokla/t319.JPG
# /kaggle/input/readyset/course/test1/dhokla/t283.JPG
# /kaggle/input/readyset/course/test1/dhokla/t300.JPG
# /kaggle/input/readyset/course/test1/dhokla/t241.JPG
# /kaggle/input/readyset/course/test1/dhokla/t263.JPG
# /kaggle/input/readyset/course/test1/dhokla/t278.JPG
# /kaggle/input/readyset/course/test1/dhokla/t293.JPG
# /kaggle/input/readyset/course/test1/dhokla/t259.JPG
# /kaggle/input/readyset/course/test1/dhokla/t279.JPG
# /kaggle/input/readyset/course/test1/dhokla/t255.JPG
# /kaggle/input/readyset/course/test1/dhokla/t246.JPG
# /kaggle/input/readyset/course/test1/dhokla/t290.JPG
# /kaggle/input/readyset/course/test1/dhokla/t307.JPG
# /kaggle/input/readyset/course/test1/dhokla/t272.JPG
# /kaggle/input/readyset/course/test1/dhokla/t252.JPG
# /kaggle/input/readyset/course/test1/dhokla/t267.JPG
# /kaggle/input/readyset/course/test1/dhokla/t313.JPG
# /kaggle/input/readyset/course/test1/dhokla/t291.JPG
# /kaggle/input/readyset/course/test1/dhokla/t298.JPG
# /kaggle/input/readyset/course/test1/dhokla/t257.JPG
# /kaggle/input/readyset/course/test1/dhokla/t249.JPG
# /kaggle/input/readyset/course/test1/dhokla/t318.JPG
# /kaggle/input/readyset/course/test1/dhokla/t311.JPG
# /kaggle/input/readyset/course/test1/dhokla/t288.JPG
# /kaggle/input/readyset/course/test1/dhokla/t251.JPG
# /kaggle/input/readyset/course/test1/dhokla/t250.JPG
# /kaggle/input/readyset/course/test1/dhokla/t286.JPG
# /kaggle/input/readyset/course/test1/dhokla/t315.JPG
# /kaggle/input/readyset/course/test1/dhokla/t280.JPG
# /kaggle/input/readyset/course/test1/dhokla/t304.JPG
# /kaggle/input/readyset/course/test1/dhokla/t266.JPG
# /kaggle/input/readyset/course/test1/dhokla/t261.JPG
# /kaggle/input/readyset/course/test1/dhokla/t277.JPG
# /kaggle/input/readyset/course/test1/dhokla/t295.JPG
# /kaggle/input/readyset/course/test1/dhokla/t273.JPG
# /kaggle/input/readyset/course/test1/dhokla/t317.JPG
# /kaggle/input/readyset/course/test1/dhokla/t256.JPG
# /kaggle/input/readyset/course/test1/dhokla/t305.JPG
# /kaggle/input/readyset/course/test1/dhokla/t274.JPG
# /kaggle/input/readyset/course/test1/dhokla/t244.JPG
# /kaggle/input/readyset/course/test1/dhokla/t258.JPG
# /kaggle/input/readyset/course/test1/dhokla/t292.JPG
# /kaggle/input/readyset/course/test1/dhokla/t308.JPG
# /kaggle/input/readyset/course/test1/dhokla/t270.JPG
# /kaggle/input/readyset/course/test1/dhokla/t271.JPG
# /kaggle/input/readyset/course/test1/dhokla/t306.JPG
# /kaggle/input/readyset/course/test1/dhokla/t260.JPG
# /kaggle/input/readyset/course/test1/dhokla/t265.JPG
# /kaggle/input/readyset/course/test1/dhokla/t309.JPG
# /kaggle/input/readyset/course/test1/dhokla/t287.JPG
# /kaggle/input/readyset/course/test1/dhokla/t276.JPG
# /kaggle/input/readyset/course/test1/dhokla/t285.JPG
# /kaggle/input/readyset/course/test1/dhokla/t296.JPG
# /kaggle/input/readyset/course/test1/dhokla/t312.JPG
# /kaggle/input/readyset/course/test1/dhokla/t310.JPG
# /kaggle/input/readyset/course/test1/dhokla/t275.JPG
# /kaggle/input/readyset/course/test1/dhokla/t299.JPG
# /kaggle/input/readyset/course/test1/dhokla/t302.JPG
# /kaggle/input/readyset/course/test1/dhokla/t294.JPG
# /kaggle/input/readyset/course/test1/dhokla/t243.JPG
# /kaggle/input/readyset/course/test1/dhokla/t254.JPG
# /kaggle/input/readyset/course/test1/dhokla/t303.JPG
# /kaggle/input/readyset/course/test1/dhokla/t268.JPG
# /kaggle/input/readyset/course/test1/dhokla/t240.JPG
# /kaggle/input/readyset/course/test1/dhokla/t248.JPG
# /kaggle/input/readyset/course/test1/dhokla/t282.JPG
# /kaggle/input/readyset/course/test1/dhokla/t320.JPG
# /kaggle/input/readyset/course/test1/dhokla/t281.JPG
# /kaggle/input/readyset/course/test1/dhokla/t245.JPG
# /kaggle/input/readyset/course/test1/dhokla/t269.JPG
# /kaggle/input/readyset/course/test1/dhokla/t264.JPG
# /kaggle/input/readyset/course/test1/dhokla/t321.JPG
# /kaggle/input/readyset/course/test1/dhokla/t301.JPG
# /kaggle/input/readyset/course/test1/dhokla/t314.JPG
# /kaggle/input/readyset/course/test1/dhokla/t242.JPG
# /kaggle/input/readyset/course/test1/dhokla/t297.JPG
# /kaggle/input/readyset/course/test1/dhokla/t262.JPG
# /kaggle/input/readyset/course/test1/dhokla/t253.JPG
# /kaggle/input/readyset/course/test1/dhokla/t284.JPG
# /kaggle/input/readyset/course/test1/dhokla/t316.JPG
# /kaggle/input/readyset/course/test1/dhokla/t289.JPG
# /kaggle/input/readyset/course/test1/chicken/t133.JPG
# /kaggle/input/readyset/course/test1/chicken/t142.JPG
# /kaggle/input/readyset/course/test1/chicken/t131.JPG
# /kaggle/input/readyset/course/test1/chicken/t143.JPG
# /kaggle/input/readyset/course/test1/chicken/t236.JPG
# /kaggle/input/readyset/course/test1/chicken/t136.JPG
# /kaggle/input/readyset/course/test1/chicken/t147.JPG
# /kaggle/input/readyset/course/test1/chicken/t206.JPG
# /kaggle/input/readyset/course/test1/chicken/t209.JPG
# /kaggle/input/readyset/course/test1/chicken/t238.JPG
# /kaggle/input/readyset/course/test1/chicken/t203.JPG
# /kaggle/input/readyset/course/test1/chicken/t230.JPG
# /kaggle/input/readyset/course/test1/chicken/t140.JPG
# /kaggle/input/readyset/course/test1/chicken/t215.JPG
# /kaggle/input/readyset/course/test1/chicken/t117.JPG
# /kaggle/input/readyset/course/test1/chicken/t153.JPG
# /kaggle/input/readyset/course/test1/chicken/t232.JPG
# /kaggle/input/readyset/course/test1/chicken/t124.JPG
# /kaggle/input/readyset/course/test1/chicken/t207.JPG
# /kaggle/input/readyset/course/test1/chicken/t135.JPG
# /kaggle/input/readyset/course/test1/chicken/t118.JPG
# /kaggle/input/readyset/course/test1/chicken/t237.JPG
# /kaggle/input/readyset/course/test1/chicken/t222.JPG
# /kaggle/input/readyset/course/test1/chicken/t127.JPG
# /kaggle/input/readyset/course/test1/chicken/t108.JPG
# /kaggle/input/readyset/course/test1/chicken/t128.JPG
# /kaggle/input/readyset/course/test1/chicken/t233.JPG
# /kaggle/input/readyset/course/test1/chicken/t201.JPG
# /kaggle/input/readyset/course/test1/chicken/t130.JPG
# /kaggle/input/readyset/course/test1/chicken/t105.JPG
# /kaggle/input/readyset/course/test1/chicken/t220.JPG
# /kaggle/input/readyset/course/test1/chicken/t148.JPG
# /kaggle/input/readyset/course/test1/chicken/t151.JPG
# /kaggle/input/readyset/course/test1/chicken/t137.JPG
# /kaggle/input/readyset/course/test1/chicken/t132.JPG
# /kaggle/input/readyset/course/test1/chicken/t111.JPG
# /kaggle/input/readyset/course/test1/chicken/t125.JPG
# /kaggle/input/readyset/course/test1/chicken/t198.JPG
# /kaggle/input/readyset/course/test1/chicken/t126.JPG
# /kaggle/input/readyset/course/test1/chicken/t234.JPG
# /kaggle/input/readyset/course/test1/chicken/t225.JPG
# /kaggle/input/readyset/course/test1/chicken/t106.JPG
# /kaggle/input/readyset/course/test1/chicken/t134.JPG
# /kaggle/input/readyset/course/test1/chicken/t213.JPG
# /kaggle/input/readyset/course/test1/chicken/t101.JPG
# /kaggle/input/readyset/course/test1/chicken/t145.JPG
# /kaggle/input/readyset/course/test1/chicken/t102.JPG
# /kaggle/input/readyset/course/test1/chicken/t152.JPG
# /kaggle/input/readyset/course/test1/chicken/t224.JPG
# /kaggle/input/readyset/course/test1/chicken/t160.JPG
# /kaggle/input/readyset/course/test1/chicken/t197.JPG
# /kaggle/input/readyset/course/test1/chicken/t146.JPG
# /kaggle/input/readyset/course/test1/chicken/t221.JPG
# /kaggle/input/readyset/course/test1/chicken/t229.JPG
# /kaggle/input/readyset/course/test1/chicken/t107.JPG
# /kaggle/input/readyset/course/test1/chicken/t138.JPG
# /kaggle/input/readyset/course/test1/chicken/t204.JPG
# /kaggle/input/readyset/course/test1/chicken/t155.JPG
# /kaggle/input/readyset/course/test1/chicken/t129.JPG
# /kaggle/input/readyset/course/test1/chicken/t149.JPG
# /kaggle/input/readyset/course/test1/chicken/t150.JPG
# /kaggle/input/readyset/course/test1/chicken/t200.JPG
# /kaggle/input/readyset/course/test1/chicken/t218.JPG
# /kaggle/input/readyset/course/test1/chicken/t219.JPG
# /kaggle/input/readyset/course/test1/chicken/t214.JPG
# /kaggle/input/readyset/course/test1/chicken/t116.JPG
# /kaggle/input/readyset/course/test1/chicken/t104.JPG
# /kaggle/input/readyset/course/test1/chicken/t208.JPG
# /kaggle/input/readyset/course/test1/chicken/t112.JPG
# /kaggle/input/readyset/course/test1/chicken/t202.JPG
# /kaggle/input/readyset/course/test1/chicken/t139.JPG
# /kaggle/input/readyset/course/test1/chicken/t157.JPG
# /kaggle/input/readyset/course/test1/chicken/t154.JPG
# /kaggle/input/readyset/course/test1/chicken/t141.JPG
# /kaggle/input/readyset/course/test1/chicken/t156.JPG
# /kaggle/input/readyset/course/test1/chicken/t211.JPG
# /kaggle/input/readyset/course/test1/chicken/t239.JPG
# /kaggle/input/readyset/course/test1/chicken/t110.JPG
# /kaggle/input/readyset/course/test1/chicken/t144.JPG
# /kaggle/input/readyset/course/test1/chicken/t113.JPG
# /kaggle/input/readyset/course/test1/chicken/t199.JPG
# /kaggle/input/readyset/course/test1/chicken/t226.JPG
# /kaggle/input/readyset/course/test1/chicken/t159.JPG
# /kaggle/input/readyset/course/test1/chicken/t158.JPG
# /kaggle/input/readyset/course/test1/chicken/t122.JPG
# /kaggle/input/readyset/course/test1/chicken/t121.JPG
# /kaggle/input/readyset/course/test1/chicken/t223.JPG
# /kaggle/input/readyset/course/test1/chicken/t109.JPG
# /kaggle/input/readyset/course/test1/chicken/t231.JPG
# /kaggle/input/readyset/course/test1/chicken/t205.JPG
# /kaggle/input/readyset/course/test1/chicken/t235.JPG
# /kaggle/input/readyset/course/test1/chicken/t228.JPG
# /kaggle/input/readyset/course/test1/chicken/t103.JPG
# /kaggle/input/readyset/course/test1/chicken/t115.JPG
# /kaggle/input/readyset/course/test1/chicken/t114.JPG
# /kaggle/input/readyset/course/test1/chicken/t210.JPG
# /kaggle/input/readyset/course/test1/chicken/t120.JPG
# /kaggle/input/readyset/course/test1/chicken/t212.JPG
# /kaggle/input/readyset/course/test1/chicken/t217.JPG
# /kaggle/input/readyset/course/test1/chicken/t216.JPG
# /kaggle/input/readyset/course/test1/chicken/t227.JPG
# /kaggle/input/readyset/course/test1/chicken/t119.JPG
# /kaggle/input/readyset/course/test1/chicken/t123.JPG

# %%
import os
import torch
import torchvision
import tarfile
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split

# %%
data_dir = '../input/readyset/course/'

print(os.listdir(data_dir))
classes = os.listdir(data_dir + "/train1")
print(classes)
# Out:
# ['train1', 'test1']
# ['dosa', 'vadapav', 'samosa', 'butternaan', 'dhokla', 'chicken']

# %%
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor

# %%
dataset = ImageFolder(data_dir+'/train1', transform=ToTensor())

# %%
import matplotlib.pyplot as plt

def show_example(img, label):
    print('Label: ', dataset.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1, 2, 0))

# %%
show_example(*dataset[0])
# Out:
# Label:  butternaan (0)

# %%
random_seed = 42
torch.manual_seed(random_seed);

# %%
val_size = 650
train_size = len(dataset) - val_size

train_ds, val_ds = random_split(dataset, [train_size, val_size])
len(train_ds), len(val_ds)
# Out:
# (5003, 650)

# %%
from torch.utils.data.dataloader import DataLoader

batch_size=32

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class Cifar10CnnModel(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8
            #nn.Dropout2d(p=0.3),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            
            nn.MaxPool2d(2, 2), # output: 256 x 4 x 4
            nn.MaxPool2d(2,2),
            nn.Flatten(), 
            nn.Linear(256*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 6))
        
    def forward(self, xb):
        return self.network(xb)

# %%
model = Cifar10CnnModel()
model
# Out:
# Cifar10CnnModel(
#   (network): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Dropout2d(p=0.3, inplace=False)
#     (13): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Flatten()
#     (22): Linear(in_features=4096, out_features=1024, bias=True)
#     (23): ReLU()
#     (24): Linear(in_features=1024, out_features=512, bias=True)
#     (25): ReLU()
#     (26): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(model, device);

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
model = to_device(Cifar10CnnModel(), device)

# %%
evaluate(model, val_dl)
# Out:
# {'val_loss': 1.792508602142334, 'val_acc': 0.17386363446712494}

# %%
num_epochs = 15
opt_func = torch.optim.Adam
lr = 0.001

# %%
history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 1.7919, val_loss: 1.7918, val_acc: 0.1841
# Epoch [1], train_loss: 1.7916, val_loss: 1.7919, val_acc: 0.1739
# Epoch [2], train_loss: 1.7913, val_loss: 1.7916, val_acc: 0.1739
# Epoch [3], train_loss: 1.7915, val_loss: 1.7916, val_acc: 0.1739
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-151-5f6b37c59350> in <module>
# ----> 1 history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
#
# <ipython-input-146-0c522a5c70aa> in fit(epochs, lr, model, train_loader, val_loader, opt_func)
#      16             train_losses.append(loss)
#      17             loss.backward()
# ---> 18             optimizer.step()
#      19             optimizer.zero_grad()
#      20         # Validation phase
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     105                     denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     106                 else:
# --> 107                     denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     108
#     109                 step_size = group['lr'] / bias_correction1
#
# KeyboardInterrupt:

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(history)

# %%
test_dataset = ImageFolder(data_dir+'/test1', transform=ToTensor())

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %%
img, label = test_dataset[0]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))

# %%
img, label = test_dataset[398]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))

# %%
img, label = test_dataset[557]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))

# %%
img, label = test_dataset[138]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))

# %%
img, label = test_dataset[38]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))

# %%
test_loader = DeviceDataLoader(DataLoader(test_dataset, batch_size*2), device)
result = evaluate(model, test_loader)
result
